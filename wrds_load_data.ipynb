# %%
import pandas as pd
import numpy as np
import wrds

# %%
db = wrds.Connection()
# Out:
# Enter your WRDS username [XIAOXU001]: weixk
# Enter your password: ···················
# WRDS recommends setting up a .pgpass file.
# You can find more info here:
# https://www.postgresql.org/docs/9.5/static/libpq-pgpass.html.
# Loading library list...
# Done

# %%
db.list_tables(library='revere')
# Out:
# ['address_type',
#  'chars',
#  'company',
#  'company_address',
#  'company_address_type',
#  'company_alias',
#  'company_cusip',
#  'company_cusip_fs',
#  'company_factset',
#  'company_isin',
#  'company_isin_fs',
#  'company_rbics_focus_2013_l6',
#  'company_redirect',
#  'company_region',
#  'company_sector_all',
#  'company_sector_focus',
#  'company_sector_particip',
#  'company_sector_pureplay',
#  'company_sector_summary',
#  'company_security',
#  'company_sedol',
#  'company_sedol_fs',
#  'company_segrev_item',
#  'company_segrev_report',
#  'company_segrev_summary',
#  'company_ticker',
#  'company_ticker_fs',
#  'company_valoren',
#  'country',
#  'geo3_region_replacement',
#  'geo3_region_structure',
#  'geo3_report',
#  'geo3_report_item',
#  'indication',
#  'indication_sector',
#  'period_fintype',
#  'period_length_unit',
#  'place_of_listing',
#  'product',
#  'product_sector',
#  'product_type',
#  'rbics_structure_2013_l6',
#  'region',
#  'region_map',
# ...

# %%
db.list_tables(library='comp')
# Out:
# ['aco_amda',
#  'aco_imda',
#  'aco_indfnta',
#  'aco_indfntq',
#  'aco_indfntytd',
#  'aco_indsta',
#  'aco_indstq',
#  'aco_indstytd',
#  'aco_notesa',
#  'aco_notesq',
#  'aco_notessa',
#  'aco_notesytd',
#  'aco_pnfnda',
#  'aco_pnfndq',
#  'aco_pnfndytd',
#  'aco_pnfnta',
#  'aco_pnfntq',
#  'aco_pnfntytd',
#  'aco_transa',
#  'aco_transq',
#  'aco_transsa',
#  'aco_transytd',
#  'adsprate',
#  'anncomp',
#  'asec_imda',
#  'asec_notesa',
#  'asec_notesq',
#  'asec_transa',
#  'asec_transq',
#  'bank_aacctchg',
#  'bank_adesind',
#  'bank_afnd1',
#  'bank_afnd2',
#  'bank_afnddc1',
#  'bank_afnddc2',
#  'bank_afntind',
#  'bank_funda',
#  'bank_funda_fncd',
#  'bank_fundq',
#  'bank_fundq_fncd',
#  'bank_iacctchg',
#  'bank_idesind',
#  'bank_ifndq',
#  'bank_ifndytd',
#  'bank_ifntq',
#  'bank_ifntytd',
#  'bank_names',
#  'bank_namesq',
#  'chars',
#  'co_aacctchg',
#  'co_aaudit',
#  'co_adesind',
#  'co_adjfact',
#  'co_afnd1',
#  'co_afnd2',
#  'co_afnddc1',
# ...

# %%
db.list_tables(library='crsp')
# Out:
# ['acti',
#  'asia',
#  'asib',
#  'asic',
#  'asio',
#  'asix',
#  'bmdebt',
#  'bmheader',
#  'bmpaymts',
#  'bmquotes',
#  'bmyield',
#  'bndprt06',
#  'bndprt12',
#  'bxcalind',
#  'bxdlyind',
#  'bxmthind',
#  'bxquotes',
#  'bxyield',
#  'cap',
#  'ccm_lookup',
#  'ccm_qvards',
#  'ccmxpf_linktable',
#  'ccmxpf_lnkhist',
#  'ccmxpf_lnkrng',
#  'ccmxpf_lnkused',
#  'comphead',
#  'comphist',
#  'compmaster',
#  'contact_info',
#  'crsp_cik_map',
#  'crsp_daily_data',
#  'crsp_header',
#  'crsp_monthly_data',
#  'crsp_names',
#  'crsp_portno_map',
#  'crsp_ziman_daily_index',
#  'crsp_ziman_monthly_index',
#  'cs20yr',
#  'cs5yr',
#  'cs90d',
#  'cst_hist',
#  'daily_nav',
#  'daily_nav_ret',
#  'daily_returns',
#  'dividends',
#  'dport1',
#  'dport2',
#  'dport3',
#  'dport4',
#  'dport5',
#  'dport6',
#  'dport7',
#  'dport8',
#  'dport9',
#  'dsbc',
#  'dsbo',
#  'dse',
#  'dse62',
#  'dse62delist',
#  'dse62dist',
#  'dse62exchdates',
#  'dse62names',
#  'dse62nasdin',
# ...

# %%
db.list_tables(library='wrdsapps')
# Out:
# ['bondcrsp_link', 'bondret', 'firm_ratio', 'rpevts']

# %%
company = db.get_table(library='crsp', table='msf', obs = 10)

# %%
crsp_cusip = db.describe_table(library='crsp', table='msf')
# Out:
# Approximately 4464480 rows in crsp.msf.

# %%
crsp_cusip = db.get_table(library='crsp', table='msf', columns = ['cusip'])
crsp_cusip = crsp_cusip.drop_duplicates(subset='cusip', keep='first')
crsp_cusip.to_pickle('crsp_cusip.pkl')

# %%
db.describe_table(library='revere', table='company')
# Out:
# Approximately 0 rows in revere.company.
#                      name  nullable                         type
# 0                  start_      True  TIMESTAMP WITHOUT TIME ZONE
# 1                    end_      True  TIMESTAMP WITHOUT TIME ZONE
# 2                    rev_      True             DOUBLE PRECISION
# 3                      id      True                 VARCHAR(200)
# 4                    name      True                VARCHAR(1024)
# 5        name_native_lang      True                VARCHAR(1024)
# 6                  active      True                   VARCHAR(1)
# 7                 covered      True                   VARCHAR(1)
# 8                  ticker      True                VARCHAR(1024)
# 9   investor_contact_name      True                VARCHAR(1024)
# 10            home_region      True                 VARCHAR(200)
# 11                  cusip      True                VARCHAR(1024)
# 12                   isin      True                VARCHAR(1024)
# ...

# %%
company = db.get_table(library='revere', table='company', columns = ['id','ticker','cusip','home_region'])

# %%
company.tail()
# Out:
#                id ticker cusip home_region
# 1832028   7189344   None  None          GB
# 1832029   9355464   None  None          NL
# 1832030  80354678   None  None          US
# 1832031   7189344   None  None          GB
# 1832032   9355464   None  None          NL

# %%
company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1832033 entries, 0 to 1832032
# Data columns (total 4 columns):
# id             object
# ticker         object
# cusip          object
# home_region    object
# dtypes: object(4)
# memory usage: 55.9+ MB

# %%
company.to_pickle('company_raw.pkl')

# %%
company.head()
# Out:
#        id ticker     cusip sedol
# 0    1647    BPL  11823010  None
# 1    4084   FMER  33791510  None
# 2  236891   ELUX  01019820  None
# 3    6729   MPOW  62473L30  None
# 4    5101    HMT  44107P10  None

# %%
firm_ratio = db.get_table(library='wrdsapps', table='firm_ratio')

# %%
firm_ratio
# Out:
#                          0           1           2           3           4  \
# gvkey               001010      001027      001031      001040      001043
# permno               10006       28601       10014       15763       18980
# adate           1969-04-30  1969-02-28  1969-03-31  1968-12-31  1969-07-31
# qdate           1969-09-30  1969-11-30  1969-09-30  1969-09-30  1969-10-31
# public_date     1970-01-31  1970-01-31  1970-01-31  1970-01-31  1970-01-31
# capei              11.6093     34.8052     50.4905     13.1534     17.7678
# be                 219.086         NaN      22.406     178.793     200.742
# bm                0.794561         NaN    0.385953    0.366221    0.387775
# evm                6.89618     19.5091     18.1121     8.24517     8.69008
# pe_op_basic           None        None        None        None        None
# pe_op_dil             None        None        None        None        None
# ...

# %%
wrds_company = db.get_table(library='revere', table='wrds_company', columns = ['ticker','home_region','cusip','company_id','country'])

# %%
wrds_company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110412 entries, 0 to 110411
# Data columns (total 5 columns):
# ticker         57072 non-null object
# home_region    102028 non-null object
# cusip          57289 non-null object
# company_id     110412 non-null object
# country        62522 non-null object
# dtypes: object(5)
# memory usage: 4.2+ MB

# %%
comp = db.get_table(library='comp', table='funda',obs=10)

# %%
list(comp.columns)
# Out:
# ['gvkey',
#  'datadate',
#  'fyear',
#  'indfmt',
#  'consol',
#  'popsrc',
#  'datafmt',
#  'tic',
#  'cusip',
#  'conm',
#  'acctchg',
#  'acctstd',
#  'acqmeth',
#  'adrr',
#  'ajex',
#  'ajp',
#  'bspr',
#  'compst',
#  'curcd',
#  'curncd',
#  'currtr',
#  'curuscn',
#  'final',
#  'fyr',
#  'ismod',
#  'ltcm',
#  'ogm',
#  'pddur',
#  'scf',
#  'src',
#  'stalt',
#  'udpl',
#  'upd',
#  'apdedate',
#  'fdate',
#  'pdate',
#  'acchg',
#  'acco',
#  'accrt',
#  'acdo',
#  'aco',
#  'acodo',
#  'acominc',
#  'acox',
#  'acoxar',
#  'acqao',
#  'acqcshi',
#  'acqgdwl',
#  'acqic',
#  'acqintan',
#  'acqinvt',
#  'acqlntal',
#  'acqniintc',
#  'acqppe',
#  'acqsc',
#  'act',
#  'adpac',
#  'aedi',
#  'afudcc',
#  'afudci',
#  'aldo',
#  'am',
#  'amc',
#  'amdc',
#  'amgw',
#  'ano',
#  'ao',
#  'aocidergl',
#  'aociother',
#  'aocipen',
#  'aocisecgl',
#  'aodo',
#  'aol2',
#  'aoloch',
#  'aox',
#  'ap',
#  'apalch',
#  'apb',
#  'apc',
#  'apofs',
#  'aqa',
#  'aqc',
#  'aqd',
# ...

# %%
comp_cusip_1 = db.get_table(library='comp', table='funda', columns = ['cusip','tic'])

# %%
comp_cusip_1 = pd.DataFrame(comp_cusip_1['cusip'].unique(), columns = ['cusip'])
comp_cusip_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38751 entries, 0 to 38750
# Data columns (total 1 columns):
# cusip    38750 non-null object
# dtypes: object(1)
# memory usage: 302.8+ KB

# %%
comp_cusip = comp_cusip.drop_duplicates(subset='cusip', keep='first')

# %%
comp_cusip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38751 entries, 0 to 785630
# Data columns (total 2 columns):
# cusip    38750 non-null object
# tic      38745 non-null object
# dtypes: object(2)
# memory usage: 908.2+ KB

# %%
comp_cusip.head()
# Out:
#         cusip    tic
# 0   000032102   AE.2
# 8   000165100  AMFD.
# 15  000352104   AAIC
# 23  00099V004  4165A
# 53  000354100   ANTQ

# %%
comp_cusip.to_pickle('comp_cusip_api.pkl')
