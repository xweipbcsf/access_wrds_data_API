# %%
import pandas as pd
import datetime as dt
import numpy as np

# %% [markdown]
# # net_degree

# %%
net_degree_3 = pd.read_pickle('net_degree_3.pkl')

# %%
net_degree_3.head()
# Out:
#      cusip_9  out_degree_centrality  in_degree_centrality  \
# 0  000360206               0.000848              0.000000
# 1  000361105               0.000000              0.000283
# 2  00089L107               0.000283              0.000000
# 3  001084102               0.000565              0.002545
# 4  00108M102               0.000848              0.000283
#
#    closeness_centrality  betweenness_centrality  eigenvector_centrality  \
# 0              0.000000                0.000000            6.336145e-17
# 1              0.138689                0.000000            6.321229e-03
# 2              0.000000                0.000000            6.336145e-17
# 3              0.120557                0.001189            1.308002e-03
# 4              0.124502                0.000048            2.362460e-03
#
#    harmonic_centrality  average_neighbor_degree  square_clustering  \
# 0             0.000000                 2.000000                0.0
# ...

# %%
net_degree_3['year_0'].unique()
# Out:
# array(['2003-06-30', '2004-06-30', '2005-06-30', '2006-06-30',
#        '2007-06-30', '2008-06-30', '2009-06-30', '2010-06-30',
#        '2011-06-30', '2012-06-30', '2013-06-30', '2014-06-30',
#        '2015-06-30'], dtype=object)

# %%
factset_foundamental = pd.read_pickle('factset_foundamental.pkl')

# %%
factset_foundamental['year_0'].unique()
# Out:
# array(['2003-06-30', '2004-06-30', '2005-06-30', '2006-06-30',
#        '2007-06-30', '2008-06-30', '2009-06-30', '2010-06-30',
#        '2011-06-30', '2012-06-30', '2013-06-30', '2014-06-30',
#        '2015-06-30', '2016-06-30'], dtype=object)

# %%
factset_foundamental.head()
# Out:
#    FS_PERM_SEC_ID       DATE INDUSTRY_CODE SECTOR_CODE  FF_GEN_IND  \
# 15    B00M5L-S-SE 2002-12-31          1315        1300         1.0
# 31    B00N7M-S-CH 2002-12-31          1235        1200         1.0
# 47    B00QCP-S-BE 2002-12-31          3525        3500         1.0
# 52    B00RFQ-S-FR 2002-12-31          1210        1200         1.0
# 68    B00SHR-S-GB 2002-12-31          4830        4800         6.0
#
#      FF_ASSETS  FF_ASSETS_CURR_OTH  FF_ASSETS_OTH  FF_ASSET_TURN  FF_BPS_TANG  \
# 15     84.6330              0.0000         3.7760       0.295582   -15.642801
# 31  41420.1612           5720.2299       770.1639       0.598438    -1.871335
# 47    187.3910              0.0000         7.5640       1.587023    13.781538
# 52     82.8320              0.1100         0.1350       1.274577     5.754530
# 68   1535.9110                 NaN        16.7050       0.360527     0.760944
#
#        ...      FF_SALES_PS       FF_SGA  FF_SGA_OTH_EXP  FF_STK_CHG_CF  \
# ...

# %%
funda_net_degree_3 = pd.merge(net_degree_3,factset_foundamental, how = 'inner', on = ['cusip_9', 'year_0'] )

# %%
funda_net_degree_3.to_pickle('funda_net_degree_3.pkl')

# %%
funda_net_degree_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66328 entries, 0 to 66327
# Data columns (total 92 columns):
# cusip_9                    66328 non-null object
# out_degree_centrality      66328 non-null float64
# in_degree_centrality       66328 non-null float64
# closeness_centrality       66328 non-null float64
# betweenness_centrality     66328 non-null float64
# eigenvector_centrality     66328 non-null float64
# harmonic_centrality        66328 non-null float64
# average_neighbor_degree    66328 non-null float64
# square_clustering          66328 non-null float64
# core_number                66328 non-null float64
# pagerank                   66328 non-null float64
# hubs                       66328 non-null float64
# authorities                66328 non-null float64
# year_0                     66328 non-null object
# in_degree_0                66328 non-null float64
# out_degree_0               66328 non-null float64
# in_degree_1                66328 non-null float64
# ...

# %%
funda_net_degree_3.head()
# Out:
#      cusip_9  out_degree_centrality  in_degree_centrality  \
# 0  000360206               0.000813              0.000000
# 1  000361105               0.000542              0.000000
# 2  000957100               0.000542              0.000000
# 3  001031103               0.000271              0.000000
# 4  001084102               0.000542              0.001896
#
#    closeness_centrality  betweenness_centrality  eigenvector_centrality  \
# 0              0.000000                0.000000            6.589818e-18
# 1              0.000000                0.000000            6.589818e-18
# 2              0.000000                0.000000            6.589818e-18
# 3              0.000000                0.000000            6.589818e-18
# 4              0.115546                0.000721            1.337726e-03
#
#    harmonic_centrality  average_neighbor_degree  square_clustering  \
# 0             0.000000                 1.666667                0.0
# ...
