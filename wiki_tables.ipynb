# %%
import pandas as pd
import numpy as np

# %%
page = 'https://en.wikipedia.org/wiki/Global_Industry_Classification_Standard'
#infoboxes = pd.read_html(page, index_col=0, attrs={"class":"infobox"})
wikitables = pd.read_html(page, index_col=0, attrs={"class":"wikitable"})
print("Extracted {num} wikitables".format(num=len(wikitables)))
# Out:
# Extracted 1 wikitables

# %%
wikitables[0]
# Out:
#                                                           1         2  \
# 0
# Sector                                       Industry Group  Industry
# 10                                                   Energy      1010
# 10101020                     Oil & Gas Equipment & Services       NaN
# 101020                          Oil, Gas & Consumable Fuels  10102010
# 10102020                 Oil & Gas Exploration & Production       NaN
# 10102030       Oil & Gas Refining & Marketing opportunities       NaN
# 10102040                 Oil & Gas Storage & Transportation       NaN
# 10102050                            Coal & Consumable Fuels       NaN
# 15                                                Materials      1510
# 15101020                              Diversified Chemicals       NaN
# 15101030               Fertilizers & Agricultural Chemicals       NaN
# 15101040                                   Industrial Gases       NaN
# 15101050                                Specialty Chemicals       NaN
# 151020                               Construction Materials  15102010
# 151030                               Containers & Packaging  15103010
# 15103020                                    Paper Packaging       NaN
# 151040                                      Metals & Mining  15104010
# 15104020                        Diversified Metals & Mining       NaN
# 15104025                                             Copper       NaN
# 15104030                                               Gold       NaN
# 15104040                         Precious Metals & Minerals       NaN
# 15104045                                             Silver       NaN
# 15104050                                              Steel       NaN
# 151050                              Paper & Forest Products  15105010
# 15105020                                     Paper Products       NaN
# 20                                              Industrials      2010
# 201020                                    Building Products  20102010
# 201030                           Construction & Engineering  20103010
# 201040                                 Electrical Equipment  20104010
# 20104020                         Heavy Electrical Equipment       NaN
# ...                                                     ...       ...
# 45103030                        Home Entertainment Software       NaN
# 4520                        Technology Hardware & Equipment    452010
# 452020           Technology Hardware, Storage & Peripherals  45202030
# 452030       Electronic Equipment, Instruments & Components  45203010
# 45203015                              Electronic Components       NaN
# 45203020                  Electronic Manufacturing Services       NaN
# 45203030                            Technology Distributors       NaN
# 4530               Semiconductors & Semiconductor Equipment    453010
# 45301020                                     Semiconductors       NaN
# 50                               Telecommunication Services      5010
# 50101020              Integrated Telecommunication Services       NaN
# 501020                  Wireless Telecommunication Services  50102010
# 55                                                Utilities      5510
# 551020                                        Gas Utilities  55102010
# 551030                                      Multi-Utilities  55103010
# 551040                                      Water Utilities  55104010
# 551050    Independent Power and Renewable Electricity Pr...  55105010
# 55105020                              Renewable Electricity       NaN
# 60                                              Real Estate      6010
# 60101020                                   Industrial REITs       NaN
# 60101030                               Hotel & Resort REITs       NaN
# 60101040                                       Office REITs       NaN
# 60101050                                  Health Care REITs       NaN
# 60101060                                  Residential REITs       NaN
# 60101070                                       Retail REITs       NaN
# 60101080                                  Specialized REITs       NaN
# 601020                 Real Estate Management & Development  60102010
# 60102020                    Real Estate Operating Companies       NaN
# 60102030                            Real Estate Development       NaN
# 60102040                               Real Estate Services       NaN
#
#                                                      3           4  \
# 0
# Sector                                    Sub-Industry         NaN
# 10                                              Energy    101010.0
# 10101020                                           NaN         NaN
# 101020                            Integrated Oil & Gas         NaN
# 10102020                                           NaN         NaN
# 10102030                                           NaN         NaN
# 10102040                                           NaN         NaN
# 10102050                                           NaN         NaN
# 15                                           Materials    151010.0
# 15101020                                           NaN         NaN
# 15101030                                           NaN         NaN
# 15101040                                           NaN         NaN
# 15101050                                           NaN         NaN
# 151020                          Construction Materials         NaN
# 151030                        Metal & Glass Containers         NaN
# 15103020                                           NaN         NaN
# 151040                                        Aluminum         NaN
# 15104020                                           NaN         NaN
# 15104025                                           NaN         NaN
# 15104030                                           NaN         NaN
# 15104040                                           NaN         NaN
# 15104045                                           NaN         NaN
# 15104050                                           NaN         NaN
# 151050                                 Forest Products         NaN
# 15105020                                           NaN         NaN
# 20                                       Capital Goods    201010.0
# 201020                               Building Products         NaN
# 201030                      Construction & Engineering         NaN
# 201040               Electrical Components & Equipment         NaN
# 20104020                                           NaN         NaN
# ...                                                ...         ...
# 45103030                                           NaN         NaN
# 4520                          Communications Equipment  45201020.0
# 452020      Technology Hardware, Storage & Peripherals         NaN
# 452030              Electronic Equipment & Instruments         NaN
# 45203015                                           NaN         NaN
# 45203020                                           NaN         NaN
# 45203030                                           NaN         NaN
# 4530          Semiconductors & Semiconductor Equipment  45301010.0
# 45301020                                           NaN         NaN
# 50                          Telecommunication Services    501010.0
# 50101020                                           NaN         NaN
# 501020             Wireless Telecommunication Services         NaN
# 55                                           Utilities    551010.0
# 551020                                   Gas Utilities         NaN
# 551030                                 Multi-Utilities         NaN
# 551040                                 Water Utilities         NaN
# 551050    Independent Power Producers & Energy Traders         NaN
# 55105020                                           NaN         NaN
# 60                                         Real Estate    601010.0
# 60101020                                           NaN         NaN
# 60101030                                           NaN         NaN
# 60101040                                           NaN         NaN
# 60101050                                           NaN         NaN
# 60101060                                           NaN         NaN
# 60101070                                           NaN         NaN
# 60101080                                           NaN         NaN
# 601020              Diversified Real Estate Activities         NaN
# 60102020                                           NaN         NaN
# 60102030                                           NaN         NaN
# 60102040                                           NaN         NaN
#
#                                                      5           6  \
# 0
# Sector                                             NaN         NaN
# 10                         Energy Equipment & Services  10101010.0
# 10101020                                           NaN         NaN
# 101020                                             NaN         NaN
# 10102020                                           NaN         NaN
# 10102030                                           NaN         NaN
# 10102040                                           NaN         NaN
# 10102050                                           NaN         NaN
# 15                                           Chemicals  15101010.0
# 15101020                                           NaN         NaN
# 15101030                                           NaN         NaN
# 15101040                                           NaN         NaN
# 15101050                                           NaN         NaN
# 151020                                             NaN         NaN
# 151030                                             NaN         NaN
# 15103020                                           NaN         NaN
# 151040                                             NaN         NaN
# 15104020                                           NaN         NaN
# 15104025                                           NaN         NaN
# 15104030                                           NaN         NaN
# 15104040                                           NaN         NaN
# 15104045                                           NaN         NaN
# 15104050                                           NaN         NaN
# 151050                                             NaN         NaN
# 15105020                                           NaN         NaN
# 20                                 Aerospace & Defense  20101010.0
# 201020                                             NaN         NaN
# 201030                                             NaN         NaN
# 201040                                             NaN         NaN
# 20104020                                           NaN         NaN
# ...                                                ...         ...
# 45103030                                           NaN         NaN
# 4520                          Communications Equipment         NaN
# 452020                                             NaN         NaN
# 452030                                             NaN         NaN
# 45203015                                           NaN         NaN
# 45203020                                           NaN         NaN
# 45203030                                           NaN         NaN
# 4530                           Semiconductor Equipment         NaN
# 45301020                                           NaN         NaN
# 50              Diversified Telecommunication Services  50101010.0
# 50101020                                           NaN         NaN
# 501020                                             NaN         NaN
# 55                                  Electric Utilities  55101010.0
# 551020                                             NaN         NaN
# 551030                                             NaN         NaN
# 551040                                             NaN         NaN
# 551050                                             NaN         NaN
# 55105020                                           NaN         NaN
# 60        Equity Real Estate Investment Trusts (REITs)  60101010.0
# 60101020                                           NaN         NaN
# 60101030                                           NaN         NaN
# 60101040                                           NaN         NaN
# 60101050                                           NaN         NaN
# 60101060                                           NaN         NaN
# 60101070                                           NaN         NaN
# 60101080                                           NaN         NaN
# 601020                                             NaN         NaN
# 60102020                                           NaN         NaN
# 60102030                                           NaN         NaN
# 60102040                                           NaN         NaN
#
#                              7
# 0
# Sector                     NaN
# 10          Oil & Gas Drilling
# 10101020                   NaN
# 101020                     NaN
# 10102020                   NaN
# 10102030                   NaN
# 10102040                   NaN
# 10102050                   NaN
# 15         Commodity Chemicals
# 15101020                   NaN
# 15101030                   NaN
# 15101040                   NaN
# 15101050                   NaN
# 151020                     NaN
# 151030                     NaN
# 15103020                   NaN
# 151040                     NaN
# 15104020                   NaN
# 15104025                   NaN
# 15104030                   NaN
# 15104040                   NaN
# 15104045                   NaN
# 15104050                   NaN
# 151050                     NaN
# 15105020                   NaN
# 20         Aerospace & Defense
# 201020                     NaN
# 201030                     NaN
# 201040                     NaN
# 20104020                   NaN
# ...                        ...
# 45103030                   NaN
# 4520                       NaN
# 452020                     NaN
# 452030                     NaN
# 45203015                   NaN
# 45203020                   NaN
# 45203030                   NaN
# 4530                       NaN
# 45301020                   NaN
# 50        Alternative Carriers
# 50101020                   NaN
# 501020                     NaN
# 55          Electric Utilities
# 551020                     NaN
# 551030                     NaN
# 551040                     NaN
# 551050                     NaN
# 55105020                   NaN
# 60           Diversified REITs
# 60101020                   NaN
# 60101030                   NaN
# 60101040                   NaN
# 60101050                   NaN
# 60101060                   NaN
# 60101070                   NaN
# 60101080                   NaN
# 601020                     NaN
# 60102020                   NaN
# 60102030                   NaN
# 60102040                   NaN
#
# [158 rows x 7 columns]

# %%
wiki_gics = pd.DataFrame(wikitables[0])

# %%
wiki_gics = wiki_gics.reset_index()
#wiki_gics.columns = ['code','sector']

# %%
wiki_gics_01 = wiki_gics[[0,1]]
wiki_gics_01.columns = ['code', 'sector']
wiki_gics_23 = wiki_gics[[2,3]]
wiki_gics_23.columns = ['code', 'sector']
wiki_gics_45 = wiki_gics[[4,5]]
wiki_gics_45.columns = ['code', 'sector']
wiki_gics_67 = wiki_gics[[6,7]]
wiki_gics_67.columns = ['code', 'sector']

# %%
wiki_gics_23 = wiki_gics_23.dropna()
wiki_gics_45 = wiki_gics_45.dropna()
wiki_gics_67 = wiki_gics_67.dropna()

# %%
wiki_gics = pd.concat([wiki_gics_01,wiki_gics_23,wiki_gics_45,wiki_gics_67])

# %%
wiki_gics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 262 entries, 0 to 146
# Data columns (total 2 columns):
# code      262 non-null object
# sector    262 non-null object
# dtypes: object(2)
# memory usage: 6.1+ KB

# %%
wiki_gics.head()
# Out:
#        code                              sector
# 0    Sector                      Industry Group
# 1        10                              Energy
# 2  10101020      Oil & Gas Equipment & Services
# 3    101020         Oil, Gas & Consumable Fuels
# 4  10102020  Oil & Gas Exploration & Production

# %%
wiki_gics.to_pickle('gics_wiki.pkl')
